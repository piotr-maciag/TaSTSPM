# %%
import os
import sys
import time
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

sys.path.append('path/to/src')

from src.other_algorithms.run_algorithm import run_algorithm, print_sequences
from src.TaSTSPM import tastsp_algorithm
from src.Sequence import Dataset, Sequence, Element

# Define parameters
dataset_path = '../data/collisions_Seattle_processed.csv'
R = 100.0
T = 8000
thetas = [round(x * 0.01, 2) for x in range(1, 11)]
sequence_lengths = [1, 2]
num_repeats = 10

# Load dataset for TaSTSP
print("Loading dataset for TaSTSP...")
dataset_tastsp = Dataset(dataset_path)
F = list(dataset_tastsp.dataset_dict.keys())
print("Dataset loaded.")

# Function to generate random sequences
def generate_random_sequences(event_types, num_sequences):
    sequences = []
    for _ in range(num_sequences):
        random_event = random.choice(event_types)
        sequence = Sequence([Element(random_event)])
        sequences.append(sequence)
    return sequences

# Initialize results storage
execution_times = {length: [] for length in sequence_lengths}
pattern_counts = {length: [] for length in sequence_lengths}
execution_times_std = {length: [] for length in sequence_lengths}  # To store standard deviation
cst_spminer_times = []
cst_spminer_patterns = []
stbfm_times = []
stbfm_patterns = []

# Perform experiments
for theta in thetas:
    # Run CST_SPMiner
    print("Running CST_SPMiner...")
    start_time = time.time()
    result_CST_SPMiner = run_algorithm(dataset_path, R, T, theta, 'CST_SPMiner', 2)
    cst_spminer_time = time.time() - start_time
    cst_spminer_pattern_count = sum(len(level) for level in result_CST_SPMiner)
    cst_spminer_times.append(cst_spminer_time)
    cst_spminer_patterns.append(cst_spminer_pattern_count)
    print("CST_SPMiner completed.")

    # Run STBFM
    print("Running STBFM...")
    start_time = time.time()
    result_STBFM = run_algorithm(dataset_path, R, T, theta, 'STBFM', 2)
    stbfm_time = time.time() - start_time
    stbfm_pattern_count = sum(len(level) for level in result_STBFM)
    stbfm_times.append(stbfm_time)
    stbfm_patterns.append(stbfm_pattern_count)
    print("STBFM completed.")

    for length in sequence_lengths:
        times = []
        patterns = []
        for re in range(num_repeats):
            print(f"Length: {length}, Theta: {theta}, Repeat: {re}")
            stq = generate_random_sequences(F, length)
            start_time = time.time()
            result_tastsp = tastsp_algorithm(dataset_tastsp, F, R, T, theta, stq)
            times.append(time.time() - start_time)
            patterns.append(len(result_tastsp))
        average_time = np.mean(times)
        std_dev_time = np.std(times)
        average_patterns = np.mean(patterns)
        execution_times[length].append(average_time)
        execution_times_std[length].append(std_dev_time)
        pattern_counts[length].append(average_patterns)
        print(f"Length: {length}, Theta: {theta}, Avg Time: {average_time}, Std Dev: {std_dev_time}, Avg Patterns: {average_patterns}")
# Out:
# Loading dataset for TaSTSP...
# Loading data from ../data/collisions_Seattle_processed.csv
# Data read successfully: 15352 rows
# Dataset loaded.
# Running CST_SPMiner...
# Starting CST_SPMiner Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# Created 4-length sequences
# CST_SPMiner Algorithm Completed
# CST_SPMiner completed.
# Running STBFM...
# Starting STBFM Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# Created 4-length sequences
# STBFM Algorithm Completed
# STBFM completed.
# Length: 1, Theta: 0.01, Repeat: 0
# Length: 1, Theta: 0.01, Repeat: 1
# Length: 1, Theta: 0.01, Repeat: 2
# Length: 1, Theta: 0.01, Repeat: 3
# Length: 1, Theta: 0.01, Repeat: 4
# Length: 1, Theta: 0.01, Repeat: 5
# Length: 1, Theta: 0.01, Repeat: 6
# Length: 1, Theta: 0.01, Repeat: 7
# Length: 1, Theta: 0.01, Repeat: 8
# Length: 1, Theta: 0.01, Repeat: 9
# Length: 1, Theta: 0.01, Avg Time: 115.95171945095062, Std Dev: 329.4954271951825, Avg Patterns: 6.9
# Length: 2, Theta: 0.01, Repeat: 0
# Length: 2, Theta: 0.01, Repeat: 1
# Length: 2, Theta: 0.01, Repeat: 2
# Length: 2, Theta: 0.01, Repeat: 3
# Length: 2, Theta: 0.01, Repeat: 4
# Length: 2, Theta: 0.01, Repeat: 5
# Length: 2, Theta: 0.01, Repeat: 6
# Length: 2, Theta: 0.01, Repeat: 7
# Length: 2, Theta: 0.01, Repeat: 8
# Length: 2, Theta: 0.01, Repeat: 9
# Length: 2, Theta: 0.01, Avg Time: 10.626476597785949, Std Dev: 28.926300214262465, Avg Patterns: 0.0
# Running CST_SPMiner...
# Starting CST_SPMiner Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# Created 4-length sequences
# CST_SPMiner Algorithm Completed
# CST_SPMiner completed.
# Running STBFM...
# Starting STBFM Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# Created 4-length sequences
# STBFM Algorithm Completed
# STBFM completed.
# Length: 1, Theta: 0.02, Repeat: 0
# Length: 1, Theta: 0.02, Repeat: 1
# Length: 1, Theta: 0.02, Repeat: 2
# Length: 1, Theta: 0.02, Repeat: 3
# Length: 1, Theta: 0.02, Repeat: 4
# Length: 1, Theta: 0.02, Repeat: 5
# Length: 1, Theta: 0.02, Repeat: 6
# Length: 1, Theta: 0.02, Repeat: 7
# Length: 1, Theta: 0.02, Repeat: 8
# Length: 1, Theta: 0.02, Repeat: 9
# Length: 1, Theta: 0.02, Avg Time: 0.9990657091140747, Std Dev: 2.6149414535324995, Avg Patterns: 1.0
# Length: 2, Theta: 0.02, Repeat: 0
# Length: 2, Theta: 0.02, Repeat: 1
# Length: 2, Theta: 0.02, Repeat: 2
# Length: 2, Theta: 0.02, Repeat: 3
# Length: 2, Theta: 0.02, Repeat: 4
# Length: 2, Theta: 0.02, Repeat: 5
# Length: 2, Theta: 0.02, Repeat: 6
# Length: 2, Theta: 0.02, Repeat: 7
# Length: 2, Theta: 0.02, Repeat: 8
# Length: 2, Theta: 0.02, Repeat: 9
# Length: 2, Theta: 0.02, Avg Time: 20.273222661018373, Std Dev: 58.685408430247136, Avg Patterns: 0.3
# Running CST_SPMiner...
# Starting CST_SPMiner Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# Created 4-length sequences
# CST_SPMiner Algorithm Completed
# CST_SPMiner completed.
# Running STBFM...
# Starting STBFM Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# Created 4-length sequences
# STBFM Algorithm Completed
# STBFM completed.
# Length: 1, Theta: 0.03, Repeat: 0
# Length: 1, Theta: 0.03, Repeat: 1
# Length: 1, Theta: 0.03, Repeat: 2
# Length: 1, Theta: 0.03, Repeat: 3
# Length: 1, Theta: 0.03, Repeat: 4
# Length: 1, Theta: 0.03, Repeat: 5
# Length: 1, Theta: 0.03, Repeat: 6
# Length: 1, Theta: 0.03, Repeat: 7
# Length: 1, Theta: 0.03, Repeat: 8
# Length: 1, Theta: 0.03, Repeat: 9
# Length: 1, Theta: 0.03, Avg Time: 60.93337328433991, Std Dev: 173.51091552205403, Avg Patterns: 2.7
# Length: 2, Theta: 0.03, Repeat: 0
# Length: 2, Theta: 0.03, Repeat: 1
# Length: 2, Theta: 0.03, Repeat: 2
# Length: 2, Theta: 0.03, Repeat: 3
# Length: 2, Theta: 0.03, Repeat: 4
# Length: 2, Theta: 0.03, Repeat: 5
# Length: 2, Theta: 0.03, Repeat: 6
# Length: 2, Theta: 0.03, Repeat: 7
# Length: 2, Theta: 0.03, Repeat: 8
# Length: 2, Theta: 0.03, Repeat: 9
# Length: 2, Theta: 0.03, Avg Time: 6.983525109291077, Std Dev: 15.308235793299875, Avg Patterns: 0.0
# Running CST_SPMiner...
# Starting CST_SPMiner Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# Created 4-length sequences
# CST_SPMiner Algorithm Completed
# CST_SPMiner completed.
# Running STBFM...
# Starting STBFM Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# Created 4-length sequences
# STBFM Algorithm Completed
# STBFM completed.
# Length: 1, Theta: 0.04, Repeat: 0
# Length: 1, Theta: 0.04, Repeat: 1
# Length: 1, Theta: 0.04, Repeat: 2
# Length: 1, Theta: 0.04, Repeat: 3
# Length: 1, Theta: 0.04, Repeat: 4
# Length: 1, Theta: 0.04, Repeat: 5
# Length: 1, Theta: 0.04, Repeat: 6
# Length: 1, Theta: 0.04, Repeat: 7
# Length: 1, Theta: 0.04, Repeat: 8
# Length: 1, Theta: 0.04, Repeat: 9
# Length: 1, Theta: 0.04, Avg Time: 4.790433359146118, Std Dev: 12.40430348951133, Avg Patterns: 1.1
# Length: 2, Theta: 0.04, Repeat: 0
# Length: 2, Theta: 0.04, Repeat: 1
# Length: 2, Theta: 0.04, Repeat: 2
# Length: 2, Theta: 0.04, Repeat: 3
# Length: 2, Theta: 0.04, Repeat: 4
# Length: 2, Theta: 0.04, Repeat: 5
# Length: 2, Theta: 0.04, Repeat: 6
# Length: 2, Theta: 0.04, Repeat: 7
# Length: 2, Theta: 0.04, Repeat: 8
# Length: 2, Theta: 0.04, Repeat: 9
# Length: 2, Theta: 0.04, Avg Time: 3.3257664918899534, Std Dev: 4.912080772167999, Avg Patterns: 0.0
# Running CST_SPMiner...
# Starting CST_SPMiner Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# Created 4-length sequences
# CST_SPMiner Algorithm Completed
# CST_SPMiner completed.
# Running STBFM...
# Starting STBFM Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# Created 4-length sequences
# STBFM Algorithm Completed
# STBFM completed.
# Length: 1, Theta: 0.05, Repeat: 0
# Length: 1, Theta: 0.05, Repeat: 1
# Length: 1, Theta: 0.05, Repeat: 2
# Length: 1, Theta: 0.05, Repeat: 3
# Length: 1, Theta: 0.05, Repeat: 4
# Length: 1, Theta: 0.05, Repeat: 5
# Length: 1, Theta: 0.05, Repeat: 6
# Length: 1, Theta: 0.05, Repeat: 7
# Length: 1, Theta: 0.05, Repeat: 8
# Length: 1, Theta: 0.05, Repeat: 9
# Length: 1, Theta: 0.05, Avg Time: 5.532830548286438, Std Dev: 7.208906348028373, Avg Patterns: 1.2
# Length: 2, Theta: 0.05, Repeat: 0
# Length: 2, Theta: 0.05, Repeat: 1
# Length: 2, Theta: 0.05, Repeat: 2
# Length: 2, Theta: 0.05, Repeat: 3
# Length: 2, Theta: 0.05, Repeat: 4
# Length: 2, Theta: 0.05, Repeat: 5
# Length: 2, Theta: 0.05, Repeat: 6
# Length: 2, Theta: 0.05, Repeat: 7
# Length: 2, Theta: 0.05, Repeat: 8
# Length: 2, Theta: 0.05, Repeat: 9
# Length: 2, Theta: 0.05, Avg Time: 20.323248147964478, Std Dev: 56.63121773713987, Avg Patterns: 0.2
# Running CST_SPMiner...
# Starting CST_SPMiner Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# CST_SPMiner Algorithm Completed
# CST_SPMiner completed.
# Running STBFM...
# Starting STBFM Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# STBFM Algorithm Completed
# STBFM completed.
# Length: 1, Theta: 0.06, Repeat: 0
# Length: 1, Theta: 0.06, Repeat: 1
# Length: 1, Theta: 0.06, Repeat: 2
# Length: 1, Theta: 0.06, Repeat: 3
# Length: 1, Theta: 0.06, Repeat: 4
# Length: 1, Theta: 0.06, Repeat: 5
# Length: 1, Theta: 0.06, Repeat: 6
# Length: 1, Theta: 0.06, Repeat: 7
# Length: 1, Theta: 0.06, Repeat: 8
# Length: 1, Theta: 0.06, Repeat: 9
# Length: 1, Theta: 0.06, Avg Time: 11.029394245147705, Std Dev: 12.783209980595913, Avg Patterns: 1.3
# Length: 2, Theta: 0.06, Repeat: 0
# Length: 2, Theta: 0.06, Repeat: 1
# Length: 2, Theta: 0.06, Repeat: 2
# Length: 2, Theta: 0.06, Repeat: 3
# Length: 2, Theta: 0.06, Repeat: 4
# Length: 2, Theta: 0.06, Repeat: 5
# Length: 2, Theta: 0.06, Repeat: 6
# Length: 2, Theta: 0.06, Repeat: 7
# Length: 2, Theta: 0.06, Repeat: 8
# Length: 2, Theta: 0.06, Repeat: 9
# Length: 2, Theta: 0.06, Avg Time: 3.102201509475708, Std Dev: 4.331207316973074, Avg Patterns: 0.0
# Running CST_SPMiner...
# Starting CST_SPMiner Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# CST_SPMiner Algorithm Completed
# CST_SPMiner completed.
# Running STBFM...
# Starting STBFM Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# STBFM Algorithm Completed
# STBFM completed.
# Length: 1, Theta: 0.07, Repeat: 0
# Length: 1, Theta: 0.07, Repeat: 1
# Length: 1, Theta: 0.07, Repeat: 2
# Length: 1, Theta: 0.07, Repeat: 3
# Length: 1, Theta: 0.07, Repeat: 4
# Length: 1, Theta: 0.07, Repeat: 5
# Length: 1, Theta: 0.07, Repeat: 6
# Length: 1, Theta: 0.07, Repeat: 7
# Length: 1, Theta: 0.07, Repeat: 8
# Length: 1, Theta: 0.07, Repeat: 9
# Length: 1, Theta: 0.07, Avg Time: 67.76475222110749, Std Dev: 191.02964958627328, Avg Patterns: 1.6
# Length: 2, Theta: 0.07, Repeat: 0
# Length: 2, Theta: 0.07, Repeat: 1
# Length: 2, Theta: 0.07, Repeat: 2
# Length: 2, Theta: 0.07, Repeat: 3
# Length: 2, Theta: 0.07, Repeat: 4
# Length: 2, Theta: 0.07, Repeat: 5
# Length: 2, Theta: 0.07, Repeat: 6
# Length: 2, Theta: 0.07, Repeat: 7
# Length: 2, Theta: 0.07, Repeat: 8
# Length: 2, Theta: 0.07, Repeat: 9
# Length: 2, Theta: 0.07, Avg Time: 6.952244710922241, Std Dev: 14.559417122415697, Avg Patterns: 0.0
# Running CST_SPMiner...
# Starting CST_SPMiner Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# CST_SPMiner Algorithm Completed
# CST_SPMiner completed.
# Running STBFM...
# Starting STBFM Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# STBFM Algorithm Completed
# STBFM completed.
# Length: 1, Theta: 0.08, Repeat: 0
# Length: 1, Theta: 0.08, Repeat: 1
# Length: 1, Theta: 0.08, Repeat: 2
# Length: 1, Theta: 0.08, Repeat: 3
# Length: 1, Theta: 0.08, Repeat: 4
# Length: 1, Theta: 0.08, Repeat: 5
# Length: 1, Theta: 0.08, Repeat: 6
# Length: 1, Theta: 0.08, Repeat: 7
# Length: 1, Theta: 0.08, Repeat: 8
# Length: 1, Theta: 0.08, Repeat: 9
# Length: 1, Theta: 0.08, Avg Time: 60.906258535385135, Std Dev: 161.98489459379715, Avg Patterns: 1.5
# Length: 2, Theta: 0.08, Repeat: 0
# Length: 2, Theta: 0.08, Repeat: 1
# Length: 2, Theta: 0.08, Repeat: 2
# Length: 2, Theta: 0.08, Repeat: 3
# Length: 2, Theta: 0.08, Repeat: 4
# Length: 2, Theta: 0.08, Repeat: 5
# Length: 2, Theta: 0.08, Repeat: 6
# Length: 2, Theta: 0.08, Repeat: 7
# Length: 2, Theta: 0.08, Repeat: 8
# Length: 2, Theta: 0.08, Repeat: 9
# Length: 2, Theta: 0.08, Avg Time: 9.57344467639923, Std Dev: 26.100097500985438, Avg Patterns: 0.0
# Running CST_SPMiner...
# Starting CST_SPMiner Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# CST_SPMiner Algorithm Completed
# CST_SPMiner completed.
# Running STBFM...
# Starting STBFM Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# STBFM Algorithm Completed
# STBFM completed.
# Length: 1, Theta: 0.09, Repeat: 0
# Length: 1, Theta: 0.09, Repeat: 1
# Length: 1, Theta: 0.09, Repeat: 2
# Length: 1, Theta: 0.09, Repeat: 3
# Length: 1, Theta: 0.09, Repeat: 4
# Length: 1, Theta: 0.09, Repeat: 5
# Length: 1, Theta: 0.09, Repeat: 6
# Length: 1, Theta: 0.09, Repeat: 7
# Length: 1, Theta: 0.09, Repeat: 8
# Length: 1, Theta: 0.09, Repeat: 9
# Length: 1, Theta: 0.09, Avg Time: 48.17410113811493, Std Dev: 135.22448193220956, Avg Patterns: 1.3
# Length: 2, Theta: 0.09, Repeat: 0
# Length: 2, Theta: 0.09, Repeat: 1
# Length: 2, Theta: 0.09, Repeat: 2
# Length: 2, Theta: 0.09, Repeat: 3
# Length: 2, Theta: 0.09, Repeat: 4
# Length: 2, Theta: 0.09, Repeat: 5
# Length: 2, Theta: 0.09, Repeat: 6
# Length: 2, Theta: 0.09, Repeat: 7
# Length: 2, Theta: 0.09, Repeat: 8
# Length: 2, Theta: 0.09, Repeat: 9
# Length: 2, Theta: 0.09, Avg Time: 2.673720455169678, Std Dev: 3.2064637033723242, Avg Patterns: 0.0
# Running CST_SPMiner...
# Starting CST_SPMiner Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# CST_SPMiner Algorithm Completed
# CST_SPMiner completed.
# Running STBFM...
# Starting STBFM Algorithm
# Created 1-length sequences
# Created 2-length sequences
# Created 3-length sequences
# STBFM Algorithm Completed
# STBFM completed.
# Length: 1, Theta: 0.1, Repeat: 0
# Length: 1, Theta: 0.1, Repeat: 1
# Length: 1, Theta: 0.1, Repeat: 2
# Length: 1, Theta: 0.1, Repeat: 3
# Length: 1, Theta: 0.1, Repeat: 4
# Length: 1, Theta: 0.1, Repeat: 5
# Length: 1, Theta: 0.1, Repeat: 6
# Length: 1, Theta: 0.1, Repeat: 7
# Length: 1, Theta: 0.1, Repeat: 8
# Length: 1, Theta: 0.1, Repeat: 9
# Length: 1, Theta: 0.1, Avg Time: 3.855765771865845, Std Dev: 5.291145320390839, Avg Patterns: 1.0
# Length: 2, Theta: 0.1, Repeat: 0
# Length: 2, Theta: 0.1, Repeat: 1
# Length: 2, Theta: 0.1, Repeat: 2
# Length: 2, Theta: 0.1, Repeat: 3
# Length: 2, Theta: 0.1, Repeat: 4
# Length: 2, Theta: 0.1, Repeat: 5
# Length: 2, Theta: 0.1, Repeat: 6
# Length: 2, Theta: 0.1, Repeat: 7
# Length: 2, Theta: 0.1, Repeat: 8
# Length: 2, Theta: 0.1, Repeat: 9
# Length: 2, Theta: 0.1, Avg Time: 1.3461113929748536, Std Dev: 2.7982991278886207, Avg Patterns: 0.0

# %%
# Plot the execution times
plt.figure(figsize=(10, 6))
for length in sequence_lengths:
    plt.errorbar(thetas, execution_times[length], yerr=execution_times_std[length], label=f'TaSTSPM (Sequence Length={length})', capsize=5)
plt.plot(thetas, cst_spminer_times, label='CST_SPMiner', linestyle='--')
plt.plot(thetas, stbfm_times, label='STBFM', linestyle='--')
plt.xlabel('Theta')
plt.ylabel('Average Execution Time (seconds)')
plt.title('Average Execution Time for Algorithms Using Seattle Collision Dataset')
plt.legend()
plt.grid(True)
plt.show()

# Plot the number of discovered patterns
plt.figure(figsize=(10, 6))
width = 0.2  # width of the bars
x = np.arange(len(thetas))

plt.bar(x - width, cst_spminer_patterns, width, label='CST_SPMiner', color='gray')
plt.bar(x, stbfm_patterns, width, label='STBFM', color='black')
for length in sequence_lengths:
    plt.bar(x + width, pattern_counts[length], width, label=f'TaSTSPM (Sequence Length={length})')

plt.xlabel('Theta')
plt.ylabel('Average Number of Discovered Patterns')
plt.title('Average Number of Discovered Patterns for Algorithms Using Seattle Collision Dataset')
plt.xticks(x, thetas)
plt.legend()
plt.grid(True)
plt.show()
